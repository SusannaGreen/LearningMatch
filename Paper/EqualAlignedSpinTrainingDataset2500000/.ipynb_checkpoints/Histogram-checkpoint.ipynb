# %%
import numpy as np
import pandas as pd
import time
import logging

import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams.update({'font.size': 20})
matplotlib.rcParams['mathtext.fontset'] = 'stix'
matplotlib.rcParams['font.family'] = 'STIXGeneral'

# %%
#Define directory of the input and output files 
DATA_DIR = '/users/sgreen/LearningMatch/LVK/Paper/LambdaEtaEqualSpin/'

#Define location to the training and validation dataset
TRAINING_DATASET_FILE_PATH = DATA_DIR+r'1000000LambdaEtaAlignedSpinTrainingDataset.csv'
TrainingBank1 = pd.read_csv(TRAINING_DATASET_FILE_PATH)

#Define location to the training and validation dataset
TRAINING_DATASET_FILE_PATH = DATA_DIR+r'1500000DiffusedLambdaEtaAlignedSpinTrainingDataset.csv'
TrainingBank2 = pd.read_csv(TRAINING_DATASET_FILE_PATH)

#TrainingBank3 = pd.concat((TrainingBank1, TrainingBank2))
#TrainingBank3.sample(frac = 1)
#TrainingBank3.to_csv(DATA_DIR+r'100000LambdaEtaAlignedSpinValidationDataset+150000DiffusedLambdaEtaAlignedSpinValidationDataset.csv', index = False)

#plt.hist(TrainingBank3['match'], bins=90)
# Out:
# (array([  428.,  2703.,  6568.,  8296.,  7289.,  7180.,  6064.,  6616.,
#          5214.,  5691.,  4342.,  3583.,  2708.,  2211.,  1864.,  1701.,
#          1486.,  1438.,  1288.,  1316.,  1370.,  1308.,  1224.,  1224.,
#          1266.,  1483.,  1607.,  1593.,  1635.,  1613.,  1734.,  1823.,
#          1899.,  1943.,  2000.,  2107.,  2026.,  1940.,  1920.,  1984.,
#          2053.,  1940.,  1887.,  1795.,  1804.,  1725.,  1697.,  1678.,
#          1768.,  1633.,  1684.,  1696.,  1647.,  1621.,  1654.,  1625.,
#          1651.,  1728.,  1755.,  1740.,  1753.,  1730.,  1809.,  1818.,
#          1732.,  1856.,  1848.,  1870.,  2070.,  2047.,  2156.,  2135.,
#          2186.,  2278.,  2214.,  2356.,  2415.,  2658.,  2712.,  2810.,
#          2886.,  3060.,  3290.,  3550.,  3892.,  4577.,  5971.,  8163.,
#         11215., 14477.]),
#  array([0.06094857, 0.07138243, 0.08181628, 0.09225014, 0.102684  ,
#         0.11311786, 0.12355172, 0.13398557, 0.14441943, 0.15485329,
#         0.16528715, 0.175721  , 0.18615486, 0.19658872, 0.20702258,
#         0.21745644, 0.22789029, 0.23832415, 0.24875801, 0.25919187,
#         0.26962573, 0.28005958, 0.29049344, 0.3009273 , 0.31136116,
#         0.32179501, 0.33222887, 0.34266273, 0.35309659, 0.36353045,
#         0.3739643 , 0.38439816, 0.39483202, 0.40526588, 0.41569973,
#         0.42613359, 0.43656745, 0.44700131, 0.45743517, 0.46786902,
#         0.47830288, 0.48873674, 0.4991706 , 0.50960445, 0.52003831,
#         0.53047217, 0.54090603, 0.55133989, 0.56177374, 0.5722076 ,
#         0.58264146, 0.59307532, 0.60350917, 0.61394303, 0.62437689,
#         0.63481075, 0.64524461, 0.65567846, 0.66611232, 0.67654618,
#         0.68698004, 0.69741389, 0.70784775, 0.71828161, 0.72871547,
#         0.73914933, 0.74958318, 0.76001704, 0.7704509 , 0.78088476,
#         0.79131861, 0.80175247, 0.81218633, 0.82262019, 0.83305405,
#         0.8434879 , 0.85392176, 0.86435562, 0.87478948, 0.88522333,
#         0.89565719, 0.90609105, 0.91652491, 0.92695877, 0.93739262,
#         0.94782648, 0.95826034, 0.9686942 , 0.97912805, 0.98956191,
#         0.99999577]),
#  <BarContainer object of 90 artists>)

# %%
plt.figure(figsize=(9, 9))
plt.hist(TrainingBank1['match'], bins=50,  alpha=0.5, color='#8855fc', label='Normal Dataset')
plt.hist(TrainingBank2['match'], bins=50,  alpha=0.5, color='#ff3399', label='Diffused Dataset')
plt.xlabel('$\mathcal{M}$')
plt.ylabel('Count')
plt.legend(loc='upper left')
plt.savefig('match_error_histogram.png', dpi=300, bbox_inches='tight')
