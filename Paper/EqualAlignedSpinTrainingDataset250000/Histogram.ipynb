# %%
import numpy as np
import pandas as pd
import time
import logging

import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams.update({'font.size': 20})
matplotlib.rcParams['mathtext.fontset'] = 'stix'
matplotlib.rcParams['font.family'] = 'STIXGeneral'

# %%
#Define directory of the input and output files 
DATA_DIR = '/users/sgreen/LearningMatch/Paper/EqualAlignedSpinTrainingDataset250000/'

#Define location to the training and validation dataset
TRAINING_DATASET_FILE_PATH = DATA_DIR+r'150000DiffusedLambdaEtaAlignedSpinTrainingDataset.csv'
TrainingBank1 = pd.read_csv(TRAINING_DATASET_FILE_PATH)

#Define location to the training and validation dataset
TRAINING_DATASET_FILE_PATH = DATA_DIR+r'100000LambdaEtaAlignedSpinTrainingDataset.csv'
TrainingBank2 = pd.read_csv(TRAINING_DATASET_FILE_PATH)

TrainingBank3 = pd.concat((TrainingBank1, TrainingBank2))
TrainingBank3.sample(frac = 1)
TrainingBank3.to_csv(DATA_DIR+r'100000LambdaEtaAlignedSpinTrainingDataset+150000DiffusedLambdaEtaAlignedSpinTrainingDataset.csv', index = False)

#plt.hist(TrainingBank3['match'], bins=90)

# %%
plt.figure(figsize=(9, 9))
plt.hist(TrainingBank1['match'], bins=50,  alpha=0.5, color='#8855fc', label='Normal Dataset')
plt.hist(TrainingBank2['match'], bins=50,  alpha=0.5, color='#ff3399', label='Diffused Dataset')
plt.xlabel('$\mathcal{M}$')
plt.ylabel('Count')
plt.legend(loc='upper left')
plt.savefig('match_error_histogram_equal.png', dpi=300, bbox_inches='tight')
